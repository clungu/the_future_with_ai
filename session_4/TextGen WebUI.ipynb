# %% [markdown]
# # Setup environment

# %%
# !setup_env.sh textgen_webui
# Out:
# [+] ENV_NAME: textgen_webui
# [+] ENV_DIR: /space/envs
# [+] Creating virtual env textgen_webui in /space/envs/textgen_webui.
# [+] Activating env
# [+] Creating init script /space/envs/textgen_webui/bin/init_script.sh
# [+] Installing the kernel and registering as textgen_webui
# Installed kernelspec textgen_webui in /space/envs/_kernels/share/jupyter/kernels/textgen_webui
# [+] Updating the kernel init script so we can force the env bin directory into the PATH

# %%
# !pip install install torch torchvision torchaudio
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 85.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 95.3 MB/s eta 0:00:00a 0:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 98.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 95.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 KB 183.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 KB 126.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 103.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 110.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 142.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 116.6 MB/s eta 0:00:0000:0100:01
# ...

# %% [markdown]
# # Install the textgen_webui project

# %%
# install the textgen_webui project
# !mkdir -p /space/proj/textgen_webui
# !git clone https://github.com/oobabooga/text-generation-webui /space/proj/textgen_webui/text-generation-webui

# [Optional]
# linking the models directory to the data directory so we store models on the large disk
# !mkdir -p /space/data/.cache/textgen_webui/models
# !mv /space/proj/textgen_webui/text-generation-webui/models /space/data/.cache/textgen_webui
# !ln -s /space/data/.cache/textgen_webui/models /space/proj/textgen_webui/text-generation-webui/models

# installing the dependencies
# !cd text-generation-webui; pip install -r requirements.txt
# Out:
# fatal: destination path '/space/proj/textgen_webui/text-generation-webui' already exists and is not an empty directory.
# /space/proj/textgen_webui

# %% [markdown]
# # Update

# %%
# %cd /space/proj

print("[+] Removing old project")
# !rm -rf /space/proj/textgen_webui/text-generation-webui

print(f"[+] Cloning the project from ooobabooga/text-generation-webui")
# !git clone https://github.com/oobabooga/text-generation-webui /space/proj/textgen_webui/text-generation-webui

# linking the models directory to the data directory so we store models on the large disk
print(f"[+] Forcing the creation of the models directory")
# !mkdir -p /space/data/.cache/textgen_webui/models

print(f"[+] Moving the models directory to the data directory")
# !rsync -auv /space/proj/textgen_webui/text-generation-webui/models /space/data/.cache/textgen_webui

print(f"[+] Removing the models directory from the git project")
# !rm -rf /space/proj/textgen_webui/text-generation-webui/models

print(f"[+] Linking the models directory to the data directory")
# !ln -s /space/data/.cache/textgen_webui/models /space/proj/textgen_webui/text-generation-webui/models

# installing the dependencies
print(f"[+] Installing the dependencies")

# !cd /space/proj/textgen_webui/text-generation-webui; pip install -r requirements.txt
# Out:
# /space/proj
# [+] Removing old project
# [+] Cloning the project from ooobabooga/text-generation-webui
# Cloning into '/space/proj/textgen_webui/text-generation-webui'...
# remote: Enumerating objects: 14838, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 14838 (delta 104), reused 131 (delta 89), pack-reused 14676
# Receiving objects: 100% (14838/14838), 25.88 MiB | 19.30 MiB/s, done.
# Resolving deltas: 100% (10252/10252), done.
# [+] Forcing the creation of the models directory
# [+] Moving the models directory to the data directory
# sending incremental file list
# models/
# models/config.yaml
# models/place-your-models-here.txt
#
# sent 5,834 bytes  received 58 bytes  11,784.00 bytes/sec
# total size is 5,614  speedup is 0.95
# [+] Removing the models directory from the git project
# [+] Linking the models directory to the data directory
# [+] Installing the dependencies
# ...

# %%
# !cd /space/proj/textgen_webui/text-generation-webui; pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Ignoring exllamav2: markers 'platform_system != "Darwin" and platform_machine != "x86_64"' don't match your environment
# ...
#   Cloning https://github.com/oobabooga/torch-grammar.git to /tmp/pip-req-build-a6ohd2r8
#   Running command git clone --filter=blob:none --quiet https://github.com/oobabooga/torch-grammar.git /tmp/pip-req-build-a6ohd2r8
#   Resolved https://github.com/oobabooga/torch-grammar.git to commit 82850b5383a629f3b0fa1fba7d8f2aba3185ddb2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Ignoring bitsandbytes: markers 'platform_system == "Windows"' don't match your environment
# Ignoring llama-cpp-python: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version == "3.11"' don't match your environment
# ...

# %% [markdown]
# # Running the server

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0, 5, 6"

# %cd /space/proj/textgen_webui/text-generation-webui
# !python server.py --listen
# Out:
# /space/proj/textgen_webui/text-generation-webui
# /space/envs/textgen_webui/lib/python3.10/site-packages/transformers/utils/hub.py:123: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# 2023-12-14 14:29:53 WARNING:
# You are potentially exposing the web UI to the entire internet without any access password.
# You can create one with the "--gradio-auth" flag like this:
#
# --gradio-auth username:password
#
# Make sure to replace username:password with your own.
# 2023-12-14 14:29:53 INFO:Loading the extension "gallery"...
# Running on local URL:  http://0.0.0.0:7860
#
# To create a public link, set `share=True` in `launch()`.
